# %% [markdown]
# ---
# title: Read STAC metadata from WorldPop
# short_title: Read STAC metadata
# ---
#
# In this notebook...

# %%
from dhis2eo.data import stac

# %%
worldpop = stac.WorldPop()

# %%
worldpop.list_properties()
# Out:
# {'years': ['2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2022',
#   '2023',
#   '2024',
#   '2025',
#   '2026',
#   '2027',
#   '2028',
#   '2029',
#   '2030'],
#  'version': ['v1'],
#  'projects': ['Population', 'Age and Sex Structures'],
#  'resolutions': ['100m', '1km']}

# %%
worldpop.list_countries()
# Out:
# {'countries': [{'id': 'ABW', 'title': 'Aruba (ABW)'},
#   {'id': 'AFG', 'title': 'Afghanistan (AFG)'},
#   {'id': 'AGO', 'title': 'Angola (AGO)'},
#   {'id': 'AIA', 'title': 'Anguilla (AIA)'},
#   {'id': 'ALA', 'title': 'Åland Islands (ALA)'},
#   {'id': 'ALB', 'title': 'Albania (ALB)'},
#   {'id': 'AND', 'title': 'Andorra (AND)'},
#   {'id': 'ARE', 'title': 'United Arab Emirates (ARE)'},
#   {'id': 'ARG', 'title': 'Argentina (ARG)'},
#   {'id': 'ARM', 'title': 'Armenia (ARM)'},
#   {'id': 'ASM', 'title': 'American Samoa (ASM)'},
#   {'id': 'ATF', 'title': 'French Southern Territories (ATF)'},
#   {'id': 'ATG', 'title': 'Antigua and Barbuda (ATG)'},
#   {'id': 'AUS', 'title': 'Australia (AUS)'},
#   {'id': 'AUT', 'title': 'Austria (AUT)'},
#   {'id': 'AZE', 'title': 'Azerbaijan (AZE)'},
#   {'id': 'BDI', 'title': 'Burundi (BDI)'},
#   {'id': 'BEL', 'title': 'Belgium (BEL)'},
#   {'id': 'BEN', 'title': 'Benin (BEN)'},
# ...

# %%
worldpop.find_country_code("No")
# Out:
# {'countries': [{'id': 'IOT', 'title': 'British Indian Ocean Territory (IOT)'},
#   {'id': 'LBN', 'title': 'Lebanon (LBN)'},
#   {'id': 'MKD', 'title': 'North Macedonia (MKD)'},
#   {'id': 'MNP', 'title': 'Northern Mariana Islands (MNP)'},
#   {'id': 'NFK', 'title': 'Norfolk Island (NFK)'},
#   {'id': 'NOR', 'title': 'Norway (NOR)'},
#   {'id': 'OMN', 'title': 'Oman (OMN)'},
#   {'id': 'SMR', 'title': 'San Marino (SMR)'},
#   {'id': 'UMI', 'title': 'United States Minor Outlying Islands (UMI)'}]}
