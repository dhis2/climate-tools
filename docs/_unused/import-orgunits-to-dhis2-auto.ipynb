# %% [markdown]
# ---
# title: Importing org units to DHIS2
# short_title: Import to DHIS2
# ---

# %% [markdown]
# Here we show how to generate and import an entirely new DHIS2 org unit hierarchy programmatically from local org unit boundary data.

# %%
import geopandas as gpd
from dhis2eo.integrations.geopandas import geodataframe_to_dhis2_org_units

# %% [markdown]
# ## Load your local boundary data
#
# First, we load your local boundary data into a GeoPandas dataframe. This is typically only for a single organisation unit level, e.g. provinces. The current functionality currently only supports the first topmost level under the national.

# %% [markdown]
# Using `geopandas` we can load the data from any file format, such as shapefiles:

# %%
gdf = gpd.read_file('../data/sierra-leone-districts.shp')

# %% [markdown]
# Or GeoJSON files:

# %%
gdf = gpd.read_file('../data/sierra-leone-districts.geojson')

# %% [markdown]
# Let's inspect the contents of the organisation units data:

# %%
gdf
# Out:
#             type           id          name  hasCoordinatesDown  \
# 0        Polygon  O6uvpzGd5pu            Bo                True
# 1        Polygon  fdc6uOvgoji       Bombali                True
# 2   MultiPolygon  lc3eMKXaEfw        Bonthe                True
# 3        Polygon  jUb8gELQApl      Kailahun                True
# 4   MultiPolygon  PMa2VCrupOd        Kambia                True
# 5        Polygon  kJq2mPyFEHo        Kenema                True
# 6        Polygon  qhqAxPSTUXp     Koinadugu                True
# 7        Polygon  Vth0fbpFcsO          Kono                True
# 8   MultiPolygon  jmIPBj66vD6       Moyamba                True
# 9   MultiPolygon  TEQlaapDQoK     Port Loko                True
# 10  MultiPolygon  bL4ooGhyHRQ       Pujehun                True
# 11       Polygon  eIQbndfxQMb     Tonkolili                True
# 12  MultiPolygon  at6UHUQatSo  Western Area                True
#
#     hasCoordinatesUp  level grandParentParentGraph grandParentId  parentGraph  \
# 0              False      2                                       ImspTQPwCqd
# 1              False      2                                       ImspTQPwCqd
# 2              False      2                                       ImspTQPwCqd
# 3              False      2                                       ImspTQPwCqd
# 4              False      2                                       ImspTQPwCqd
# 5              False      2                                       ImspTQPwCqd
# 6              False      2                                       ImspTQPwCqd
# 7              False      2                                       ImspTQPwCqd
# 8              False      2                                       ImspTQPwCqd
# 9              False      2                                       ImspTQPwCqd
# 10             False      2                                       ImspTQPwCqd
# 11             False      2                                       ImspTQPwCqd
# 12             False      2                                       ImspTQPwCqd
#
#        parentId    parentName dimensions  weight  \
# 0   ImspTQPwCqd  Sierra Leone        { }       1
# 1   ImspTQPwCqd  Sierra Leone        { }       1
# 2   ImspTQPwCqd  Sierra Leone        { }       1
# 3   ImspTQPwCqd  Sierra Leone        { }       1
# 4   ImspTQPwCqd  Sierra Leone        { }       1
# 5   ImspTQPwCqd  Sierra Leone        { }       1
# 6   ImspTQPwCqd  Sierra Leone        { }       1
# 7   ImspTQPwCqd  Sierra Leone        { }       1
# 8   ImspTQPwCqd  Sierra Leone        { }       1
# 9   ImspTQPwCqd  Sierra Leone        { }       1
# 10  ImspTQPwCqd  Sierra Leone        { }       1
# 11  ImspTQPwCqd  Sierra Leone        { }       1
# 12  ImspTQPwCqd  Sierra Leone        { }       1
#
#                                              geometry
# 0   POLYGON ((-11.5914 8.4875, -11.5906 8.4769, -1...
# 1   POLYGON ((-11.8091 9.2032, -11.8102 9.1944, -1...
# 2   MULTIPOLYGON (((-12.5568 7.3832, -12.5574 7.38...
# 3   POLYGON ((-10.7972 7.5866, -10.8002 7.5878, -1...
# 4   MULTIPOLYGON (((-13.1349 8.8471, -13.1343 8.84...
# 5   POLYGON ((-11.3596 8.5317, -11.3513 8.5234, -1...
# 6   POLYGON ((-10.585 9.0434, -10.5877 9.0432, -10...
# 7   POLYGON ((-10.585 9.0434, -10.5848 9.0432, -10...
# 8   MULTIPOLYGON (((-12.6351 7.6613, -12.6346 7.66...
# 9   MULTIPOLYGON (((-13.119 8.4718, -13.1174 8.470...
# 10  MULTIPOLYGON (((-11.5346 6.944, -11.5338 6.943...
# 11  POLYGON ((-11.3546 8.6455, -11.357 8.6345, -11...
# 12  MULTIPOLYGON (((-13.2435 8.1007, -13.2429 8.10...

# %% [markdown]
# ## Convert to DHIS2 format
#
# Next, we simply pass this geodataframe to our `dhis2eo` utility function to convert to the formats required by DHIS2. What this does is create organisation units for each of the entries in the geodataframe, as well as a toplevel organisation unit for the entire country. More complex organisation unit hierarchies with multiple nested levels are not currently supported.

# %%
dhis2_metadata, dhis2_geojson = geodataframe_to_dhis2_org_units(gdf, country='Sierra Leone', name_field='Name')

# %% [markdown]
# This function returns two results. First, the DHIS2 JSON payload to generate the org unit metadata:

# %%
dhis2_metadata['organisationUnits'][:3]
# Out:
# [{'id': 'NpciiKIqKaU',
#   'name': 'Sierra Leone',
#   'shortName': 'Sierra Leone',
#   'openingDate': '2025-10-03',
#   'level': 1},
#  {'id': 'R3bFNJaZAT8',
#   'name': None,
#   'shortName': 'Unnamed',
#   'openingDate': '2025-10-03',
#   'level': 2,
#   'parent': {'id': 'NpciiKIqKaU'}},
#  {'id': 'P9yMVrCLXNs',
#   'name': None,
#   'shortName': 'Unnamed',
#   'openingDate': '2025-10-03',
#   'level': 2,
#   'parent': {'id': 'NpciiKIqKaU'}}]

# %% [markdown]
# Second, the function returns a GeoJSON containing the geometries that match and link with the org unit metadata:

# %%
dhis2_geojson['features'][0] # showing first org unit only
# Out:
# {'id': 'R3bFNJaZAT8',
#  'type': 'Feature',
#  'properties': {'id': 'R3bFNJaZAT8',
#   'name': None,
#   'shortName': 'Unnamed',
#   'openingDate': '2025-10-03',
#   'level': 2,
#   'parent': {'id': 'NpciiKIqKaU'}},
#  'geometry': {'type': 'Polygon',
#   'coordinates': (((-11.5914, 8.4875),
#     (-11.5906, 8.4769),
#     (-11.5898, 8.4717),
#     (-11.5882, 8.466),
#     (-11.5863, 8.4604),
#     (-11.5837, 8.4549),
#     (-11.5804, 8.4505),
#     (-11.5772, 8.4477),
#     (-11.5738, 8.4456),
#     (-11.5622, 8.44),
#     (-11.558, 8.4365),
#     (-11.5567, 8.4332),
#     (-11.5565, 8.4295),
#     (-11.558, 8.4215),
#     (-11.5582, 8.4185),
#     (-11.5569, 8.4121),
#     (-11.5567, 8.4084),
#     (-11.5571, 8.4047),
#     (-11.5589, 8.3968),
#     (-11.5588, 8.3927),
#     (-11.5574, 8.3877),
#     (-11.5549, 8.3835),
#     (-11.5506, 8.3751),
#     (-11.5488, 8.3707),
#     (-11.5438, 8.3562),
#     (-11.7574, 8.4152),
#     (-11.7544, 8.4194),
#     (-11.7434, 8.4316),
#     (-11.7387, 8.44),
#     (-11.7349, 8.4486),
#     (-11.7335, 8.4531),
#     (-11.7321, 8.4599),
#     (-11.7308, 8.4645),
#     (-11.7281, 8.4708),
#     (-11.7259, 8.4736),
#     (-11.7218, 8.477),
#     (-11.7175, 8.4819),
#     (-11.7146, 8.4842),
#     (-11.7103, 8.487),
#     (-11.7061, 8.4848),
#     (-11.6984, 8.4803),
#     (-11.6889, 8.482),
#     (-11.6765, 8.4832),
#     (-11.6674, 8.4855),
#     (-11.6626, 8.4861),
#     (-11.6527, 8.4864),
#     (-11.6095, 8.4863),
#     (-11.5914, 8.4875)),)},
#  'bbox': (-12.1483, 7.4835, -11.3418, 8.4875)}

# %% [markdown]
# ## Import to DHIS2
#
# Next, we use the `python-dhis2-client` to push these results to our DHIS2 instance.

# %% [markdown]
# We start by connecting to our DHIS2 instance:

# %%
from dhis2_client import DHIS2Client
from dhis2_client.settings import ClientSettings

# Client configuration
cfg = ClientSettings(
  base_url="http://localhost:8080",
  username="admin",
  password="district")

client = DHIS2Client(settings=cfg)
info = client.get_system_info()

# Check if everything is working.
# You should see your current DHIS2 version info.
print("▶ Current DHIS2 version:", info["version"])
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[15], line 11
#       5 cfg = ClientSettings(
#       6   base_url="http://localhost:8080",
#       7   username="admin",
#       8   password="district")
#      10 client = DHIS2Client(settings=cfg)
# ---> 11 info = client.get_system_info()
#      13 # Check if everything is working.
#      14 # You should see your current DHIS2 version info.
#      15 print("▶ Current DHIS2 version:", info["version"])
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\dhis2_client\client.py:252, in DHIS2Client.get_system_info(self)
#     251 def get_system_info(self) -> Dict[str, Any]:
# --> 252     return self._system.info()
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\dhis2_client\resources\system.py:6, in System.info(self)
#       5 def info(self) -> dict:
# ----> 6     return self._get("/api/system/info")
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\dhis2_client\resources\base.py:14, in Resource._get(self, path, params)
#      13 def _get(self, path: str, params: Optional[Dict[str, Any]] = None) -> Dict[str, Any]:
# ---> 14     return self._c.get(path, params=params)
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\dhis2_client\client.py:191, in DHIS2Client.get(self, path, params)
#     190 def get(self, path: str, *, params: Optional[Dict[str, Any]] = None) -> Dict[str, Any]:
# --> 191     return self._request("GET", path, params=params)
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\dhis2_client\client.py:161, in DHIS2Client._request(self, method, path, params, json)
#     159 for attempt in range(self.retries + 1):
#     160     client = self._ensure_client()
# --> 161     resp = client.request(method, url, params=params, json=json, auth=self._auth)
#     162     if resp.status_code >= 500 and method.upper() == "GET" and attempt < self.retries:
#     163         logger.warning(
#     164             "Retrying %s %s after server error %s (attempt %s)",
#     165             method,
#    (...)    168             attempt + 1,
#     169         )
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     235 import httpcore
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     160     value = typ()
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#     167     return exc is not value
#
# File c:\Users\karimba\AppData\Local\miniconda3\envs\climate-tools-new\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it

# %% [markdown]
# Then, we can use the `dhis2-python-client` to push the metadata and create the organisation unit hierarchy to DHIS2:

# %% [markdown]
# Lastly, we use the client to push the geojson file to import and attach geometries to each of the DHIS2 organisation units:

# %% [markdown]
# To confirm that DHIS2 now contains the imported organisation units with boundary geometries, we can use the client to get the current organisation units:

# %%
for ou in islice(client.get_organisation_units(level=3, fields="id,name", order="name:asc"), 10):
    print(f"{ou['id']} · {ou['name']}")
