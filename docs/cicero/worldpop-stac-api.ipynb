# %%
from pystac_client import Client

# %%
# No catalog available?
# catalog = Client.open("https://api.stac.worldpop.org")

# %%
worldpop_stac_api_url = "https://stac.worldpop.org/"
client = Client.open(worldpop_stac_api_url)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[11], line 2
#       1 worldpop_stac_api_url = "https://stac.worldpop.org/"
# ----> 2 client = Client.open(worldpop_stac_api_url)
#
# File ~/miniforge3/lib/python3.10/site-packages/pystac_client/client.py:170, in Client.open(cls, url, headers, parameters, ignore_conformance, modifier, request_modifier, stac_io, timeout)
#      98 @classmethod
#      99 def open(
#     100     cls,
#    (...)
#     108     timeout: Timeout | None = None,
#     109 ) -> "Client":
#     110     """Opens a STAC Catalog or API
#     111     This function will read the root catalog of a STAC Catalog or API
#     112
#    (...)
#     168         catalog : A :class:`Client` instance for this Catalog/API
#     169     """
# --> 170     client: Client = cls.from_file(
#     171         url,
#     172         headers=headers,
# ...
